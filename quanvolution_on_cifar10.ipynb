# %%
import pennylane as qml
# Just like standard NumPy, but with the added benefit of automatic differentiation
from pennylane import numpy as np
from pennylane.templates import RandomLayers
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
n_epochs = 30
n_layers = 1
n_train = 100
n_test = 40

SAVE_PATH = "./quanvolution2/"
PREPROCESS = True           # False --> skip quantum processing and load data from SAVE_PATH
np.random.seed(0)
tf.random.set_seed(0)

# %% [markdown]
# ## CIFAR10 data
# Here we'll be using the CIFAR10 dataset instead of the MNIST

# %%
cifar_dataset = keras.datasets.cifar10
(train_images, train_labels), (test_images, test_labels) = cifar_dataset.load_data()

# Reduce dataset size
train_images = train_images[:n_train]
train_labels = train_labels[:n_train]
test_images = test_images[:n_test]
test_labels = test_labels[:n_test]

# Normalize pixel values within 0 and 1
train_images = train_images / 255
test_images = test_images / 255

# Add extra dimension (for convolution channels)
train_images = np.array(train_images[..., tf.newaxis], requires_grad=False)
test_images = np.array(test_images[..., tf.newaxis], requires_grad=False)

# %% [markdown]
# ### The Quantum circuit as the convolution kernel

# %%
dev = qml.device("default.qubit", wires=4)

# Random circuit parameters
rand_params = np.random.uniform(high=2*np.pi, size=(n_layers, 4))

# Generate some random classical data
data = np.random.uniform(low=-np.pi, high=np.pi, size=(4,))

# To convert the function into a QNode running on dev, we apply the qnode() decorator
@qml.qnode(dev)
def circuit(phi):
    # Encoding of 4 classical input values
    for j in range(4):
        qml.RY(np.pi*phi[j], wires=j)
        # qml.Hadamard(wires=j)

    # Random quantum circuit
    RandomLayers(rand_params, wires=list(range(4)))

    # Measurement (expect. val.) producing 4 classical outputs
    return [qml.expval(qml.PauliZ(j)) for j in range(4)]

# %%
def quanv(image):
    """Convolves the input image with many applications of the same quantum circuit"""
    out = np.zeros((14, 14, 4))

    # Loop over the coordinates of the top-left pixel of 2X2 squares
    for j in range(0, 28, 2):
        for k in range(0, 28, 2):
            # Process a 2x2 region with the quantum circuit
            q_results = circuit(
                [image[j, k, 0], image[j, k + 1, 0],
                 image[j + 1, k, 0], image[j + 1, k + 1, 0]]
            )
            # Assign expectation values to different channels of the output pixel (j/2, k/2)
            for c in range(4):
                out[j // 2, k // 2, c] = q_results[c]
    return out

# %%
if PREPROCESS == True:
    q_train_images = []
    print("Quantum pre-processing of train images:")
    for idx, img in enumerate(train_images):
        print(f"{idx + 1}/{n_train}        ", end="\r")
        q_train_images.append(quanv(img))
    q_train_images = np.asarray(q_train_images)

    q_test_images = []
    print("\nQuantum pre-processing of test images:")
    for idx, img in enumerate(test_images):
        print(f"{idx + 1}/{n_test}        ", end="\r")
        q_test_images.append(quanv(img))
    q_test_images = np.asarray(q_test_images)

    # Save pre-processed images
    np.save(SAVE_PATH + "q_train_images.npy", q_train_images)
    np.save(SAVE_PATH + "q_test_images.npy", q_test_images)


# Load pre-processed images
q_train_images = np.load(SAVE_PATH + "q_train_images.npy")
q_test_images = np.load(SAVE_PATH + "q_test_images.npy")
# Out:
# Quantum pre-processing of train images:
# 1/100
# C:\Users\CSIT Lab\AppData\Local\Temp\ipykernel_41672\1039257067.py:15: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   out[j // 2, k // 2, c] = q_results[c]
# 100/100
# Quantum pre-processing of test images:
# 40/40

# %%
n_samples = 8
n_channels = 4

fig, axes = plt.subplots(1+n_channels, n_samples, figsize=(10, 10))
for k in range(n_samples):
    axes[0, 0].set_ylabel("Input")
    if k != 0:
        axes[0, k].yaxis.set_visible(False)
    axes[0, k].imshow(train_images[k, :, :, 0], cmap="gray")

    # Plot all output channels
    for c in range(n_channels):
        axes[c + 1, 0].set_ylabel(f"Output [ch. {c}]")
        if k != 0:
            axes[c, k].yaxis.set_visible(False)
        axes[c + 1, k].imshow(q_train_images[k, :, :, c], cmap="gray")

plt.tight_layout()
plt.savefig(f'out_q_layer_{n_samples}_samples.png', dpi=300, facecolor='w')
plt.show()

# %%
def model():
    """Initializes and returns a Keras model to be trained"""
    model = keras.models.Sequential([
        keras.layers.Flatten(),
        keras.layers.Dense(10, activation="softmax")
    ])

    model.compile(
        optimizer='adam',
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"],
    )
    return model


q_model = model()

q_history = q_model.fit(q_train_images, train_labels,
                        validation_data=(q_test_images, test_labels),
                        batch_size=4, epochs=n_epochs, verbose=2)


c_model = model()

c_history = c_model.fit(train_images, train_labels,
                        validation_data=(test_images, test_labels),
                        batch_size=4, epochs=n_epochs, verbose=2)
# Out:
# Epoch 1/30
# 25/25 - 1s - 22ms/step - accuracy: 0.1200 - loss: 2.4813 - val_accuracy: 0.0750 - val_loss: 2.6816
# Epoch 2/30
# 25/25 - 0s - 3ms/step - accuracy: 0.3600 - loss: 1.8788 - val_accuracy: 0.1000 - val_loss: 2.6526
# Epoch 3/30
# 25/25 - 0s - 2ms/step - accuracy: 0.5100 - loss: 1.6300 - val_accuracy: 0.1000 - val_loss: 2.7347
# Epoch 4/30
# 25/25 - 0s - 3ms/step - accuracy: 0.6500 - loss: 1.4353 - val_accuracy: 0.1000 - val_loss: 2.7980
# Epoch 5/30
# 25/25 - 0s - 3ms/step - accuracy: 0.7200 - loss: 1.2755 - val_accuracy: 0.1000 - val_loss: 2.8523
# Epoch 6/30
# 25/25 - 0s - 2ms/step - accuracy: 0.7900 - loss: 1.1384 - val_accuracy: 0.1000 - val_loss: 2.9076
# Epoch 7/30
# 25/25 - 0s - 2ms/step - accuracy: 0.8200 - loss: 1.0208 - val_accuracy: 0.1000 - val_loss: 2.9615
# Epoch 8/30
# 25/25 - 0s - 2ms/step - accuracy: 0.8500 - loss: 0.9187 - val_accuracy: 0.0750 - val_loss: 3.0148
# Epoch 9/30
# 25/25 - 0s - 3ms/step - accuracy: 0.8800 - loss: 0.8296 - val_accuracy: 0.0750 - val_loss: 3.0674
# Epoch 10/30
# 25/25 - 0s - 3ms/step - accuracy: 0.8800 - loss: 0.7514 - val_accuracy: 0.0750 - val_loss: 3.1193
# Epoch 11/30
# 25/25 - 0s - 2ms/step - accuracy: 0.9000 - loss: 0.6825 - val_accuracy: 0.0500 - val_loss: 3.1705
# Epoch 12/30
# 25/25 - 0s - 3ms/step - accuracy: 0.9300 - loss: 0.6216 - val_accuracy: 0.0500 - val_loss: 3.2209
# Epoch 13/30
# 25/25 - 0s - 2ms/step - accuracy: 0.9400 - loss: 0.5677 - val_accuracy: 0.0500 - val_loss: 3.2704
# Epoch 14/30
# 25/25 - 0s - 3ms/step - accuracy: 0.9400 - loss: 0.5198 - val_accuracy: 0.0500 - val_loss: 3.3190
# Epoch 15/30
# 25/25 - 0s - 2ms/step - accuracy: 0.9600 - loss: 0.4771 - val_accuracy: 0.0500 - val_loss: 3.3665
# Epoch 16/30
# 25/25 - 0s - 3ms/step - accuracy: 0.9700 - loss: 0.4390 - val_accuracy: 0.0500 - val_loss: 3.4130
# Epoch 17/30
# 25/25 - 0s - 2ms/step - accuracy: 0.9900 - loss: 0.4049 - val_accuracy: 0.0500 - val_loss: 3.4584
# Epoch 18/30
# 25/25 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.3742 - val_accuracy: 0.0500 - val_loss: 3.5027
# Epoch 19/30
# 25/25 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.3466 - val_accuracy: 0.0500 - val_loss: 3.5459
# Epoch 20/30
# 25/25 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.3218 - val_accuracy: 0.0500 - val_loss: 3.5880
# Epoch 21/30
# 25/25 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.2993 - val_accuracy: 0.0500 - val_loss: 3.6289
# Epoch 22/30
# 25/25 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.2790 - val_accuracy: 0.0500 - val_loss: 3.6688
# Epoch 23/30
# 25/25 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.2605 - val_accuracy: 0.0500 - val_loss: 3.7076
# Epoch 24/30
# 25/25 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.2437 - val_accuracy: 0.0500 - val_loss: 3.7453
# Epoch 25/30
# 25/25 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.2285 - val_accuracy: 0.0500 - val_loss: 3.7820
# Epoch 26/30
# 25/25 - 0s - 3ms/step - accuracy: 1.0000 - loss: 0.2145 - val_accuracy: 0.0500 - val_loss: 3.8178
# Epoch 27/30
# 25/25 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.2018 - val_accuracy: 0.0500 - val_loss: 3.8525
# Epoch 28/30
# 25/25 - 0s - 3ms/step - accuracy: 1.0000 - loss: 0.1902 - val_accuracy: 0.0250 - val_loss: 3.8864
# Epoch 29/30
# 25/25 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.1795 - val_accuracy: 0.0250 - val_loss: 3.9193
# Epoch 30/30
# 25/25 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.1696 - val_accuracy: 0.0250 - val_loss: 3.9515
# Epoch 1/30
# 25/25 - 0s - 19ms/step - accuracy: 0.0700 - loss: 3.1796 - val_accuracy: 0.1250 - val_loss: 2.5011
# Epoch 2/30
# 25/25 - 0s - 3ms/step - accuracy: 0.2400 - loss: 2.5124 - val_accuracy: 0.1500 - val_loss: 2.4345
# Epoch 3/30
# 25/25 - 0s - 3ms/step - accuracy: 0.3000 - loss: 2.3432 - val_accuracy: 0.1250 - val_loss: 2.6190
# Epoch 4/30
# 25/25 - 0s - 3ms/step - accuracy: 0.3200 - loss: 2.1688 - val_accuracy: 0.1000 - val_loss: 2.7389
# Epoch 5/30
# 25/25 - 0s - 3ms/step - accuracy: 0.3900 - loss: 1.9712 - val_accuracy: 0.0750 - val_loss: 2.8115
# Epoch 6/30
# 25/25 - 0s - 3ms/step - accuracy: 0.4400 - loss: 1.7849 - val_accuracy: 0.0750 - val_loss: 2.9138
# Epoch 7/30
# 25/25 - 0s - 3ms/step - accuracy: 0.5100 - loss: 1.6164 - val_accuracy: 0.0500 - val_loss: 3.0427
# Epoch 8/30
# 25/25 - 0s - 2ms/step - accuracy: 0.5400 - loss: 1.4652 - val_accuracy: 0.0250 - val_loss: 3.2019
# Epoch 9/30
# 25/25 - 0s - 2ms/step - accuracy: 0.6100 - loss: 1.3163 - val_accuracy: 0.0250 - val_loss: 3.3498
# Epoch 10/30
# 25/25 - 0s - 2ms/step - accuracy: 0.7000 - loss: 1.1747 - val_accuracy: 0.0750 - val_loss: 3.4557
# Epoch 11/30
# 25/25 - 0s - 2ms/step - accuracy: 0.7100 - loss: 1.0551 - val_accuracy: 0.0750 - val_loss: 3.5212
# Epoch 12/30
# 25/25 - 0s - 2ms/step - accuracy: 0.7600 - loss: 0.9543 - val_accuracy: 0.1000 - val_loss: 3.5537
# Epoch 13/30
# 25/25 - 0s - 3ms/step - accuracy: 0.7800 - loss: 0.8649 - val_accuracy: 0.1000 - val_loss: 3.5632
# Epoch 14/30
# 25/25 - 0s - 2ms/step - accuracy: 0.7900 - loss: 0.7853 - val_accuracy: 0.1000 - val_loss: 3.5611
# Epoch 15/30
# 25/25 - 0s - 2ms/step - accuracy: 0.8200 - loss: 0.7190 - val_accuracy: 0.1000 - val_loss: 3.5625
# Epoch 16/30
# 25/25 - 0s - 3ms/step - accuracy: 0.8200 - loss: 0.6689 - val_accuracy: 0.1250 - val_loss: 3.5792
# Epoch 17/30
# 25/25 - 0s - 2ms/step - accuracy: 0.8500 - loss: 0.6315 - val_accuracy: 0.1250 - val_loss: 3.6098
# Epoch 18/30
# 25/25 - 0s - 3ms/step - accuracy: 0.8600 - loss: 0.5985 - val_accuracy: 0.1250 - val_loss: 3.6391
# Epoch 19/30
# 25/25 - 0s - 2ms/step - accuracy: 0.8600 - loss: 0.5610 - val_accuracy: 0.1250 - val_loss: 3.6525
# Epoch 20/30
# 25/25 - 0s - 2ms/step - accuracy: 0.8900 - loss: 0.5162 - val_accuracy: 0.1250 - val_loss: 3.6535
# Epoch 21/30
# 25/25 - 0s - 2ms/step - accuracy: 0.9100 - loss: 0.4710 - val_accuracy: 0.1250 - val_loss: 3.6523
# Epoch 22/30
# 25/25 - 0s - 2ms/step - accuracy: 0.9100 - loss: 0.4316 - val_accuracy: 0.1250 - val_loss: 3.6482
# Epoch 23/30
# 25/25 - 0s - 2ms/step - accuracy: 0.9200 - loss: 0.3975 - val_accuracy: 0.1250 - val_loss: 3.6339
# Epoch 24/30
# 25/25 - 0s - 2ms/step - accuracy: 0.9400 - loss: 0.3654 - val_accuracy: 0.1250 - val_loss: 3.6077
# Epoch 25/30
# 25/25 - 0s - 2ms/step - accuracy: 0.9500 - loss: 0.3346 - val_accuracy: 0.1250 - val_loss: 3.5779
# Epoch 26/30
# 25/25 - 0s - 2ms/step - accuracy: 0.9700 - loss: 0.3062 - val_accuracy: 0.1000 - val_loss: 3.5559
# Epoch 27/30
# 25/25 - 0s - 3ms/step - accuracy: 0.9800 - loss: 0.2811 - val_accuracy: 0.1000 - val_loss: 3.5478
# Epoch 28/30
# 25/25 - 0s - 3ms/step - accuracy: 0.9900 - loss: 0.2595 - val_accuracy: 0.1000 - val_loss: 3.5517
# Epoch 29/30
# 25/25 - 0s - 3ms/step - accuracy: 0.9900 - loss: 0.2409 - val_accuracy: 0.1000 - val_loss: 3.5624
# Epoch 30/30
# 25/25 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.2247 - val_accuracy: 0.1000 - val_loss: 3.5760

# %%
# plt.style.use("seaborn")
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(11, 5))

ax1.plot(q_history.history["val_accuracy"], "-ob", label="With quantum layer")
ax1.plot(c_history.history["val_accuracy"], "-og", label="Without quantum layer")
ax1.set_ylabel("Accuracy")
ax1.set_ylim([0, 1])
ax1.set_xlabel("Epoch")
ax1.legend()

ax2.plot(q_history.history["val_loss"], "-ob", label="With quantum layer")
ax2.plot(c_history.history["val_loss"], "-og", label="Without quantum layer")
ax2.set_ylabel("Loss")
ax2.set_ylim(top=2.5)
ax2.set_xlabel("Epoch")
ax2.legend()

plt.tight_layout()
plt.savefig('accuracy_loss.png', dpi=200, facecolor='w')
plt.show()
